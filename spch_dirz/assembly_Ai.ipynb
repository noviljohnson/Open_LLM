# %%
asAI_key = "1d88b5e952fe49ffb56d7f68386c1044"
# `pip3 install assemblyai` (macOS)
# `pip install assemblyai` (Windows)

import assemblyai as aai

# %%
aai.settings.api_key = "1d88b5e952fe49ffb56d7f68386c1044"
transcriber = aai.Transcriber()

# %%
transcript = transcriber.transcribe("N:\DataFlo\Vdo-transcript\playlist [playlist].mp4")
# transcript = transcriber.transcribe("./my-local-audio-file.wav")

print(transcript.text)
transcript.text

# %% [markdown]
# ### Identify speaker in Audio

# %%
# Start by making sure the `assemblyai` package is installed.
# If not, you can install it by running the following command:
# pip install -U assemblyai
#
# Note: Some macOS users may need to use `pip3` instead of `pip`.

# %%
import assemblyai as aai

# Replace with your API key
aai.settings.api_key = "1d88b5e952fe49ffb56d7f68386c1044"

# %%
# URL of the file to transcribe
FILE_URL = r"N:\Open_LLM\spch_dirz\audio\sanet_finance.wav"

# %%
# You can also transcribe a local file by passing in a file path
# FILE_URL = './path/to/file.mp3'

config = aai.TranscriptionConfig(speaker_labels=True)

# %%
transcriber = aai.Transcriber()
transcript = transcriber.transcribe(
  FILE_URL,
  config=config
)

for utterance in transcript.utterances:
  print(f"Speaker {utterance.speaker}: {utterance.text}")
# Out:
# Speaker A: We don't have the capability of a scanner, so you can't scan and put the amendment up if you send it to us a day before. I don't even know if there's a scanner in the building. I think there may be one downstairs in the clerk's office. And so putting stuff electronically up amendments is something New Mexico has fallen behind with technology driven access.
# Speaker B: Well, Mr. Chair, I think it's actually a rule now. We've passed a law, maybe even said, Representative McQueen, saying that all amendments would actually have to be posted online. This may be the only, maybe all due respect, that we don't post these amendments, these documents. And I just think we should. I think it's public information and I just think nothing could be more important than a $10 billion budget from a policy standpoint and everything contained in it. So I think, Shawn, I mean, with all the other committees and legislature amendments because of that rule, what is the common practice of things being put online and how timely are those really?
# Speaker C: Mr. Chair, Senator, you're correct. The joint rule was passed a year or so ago. Last year was the first year of implementation. The posting of the amendments received by committees or when they're put on in the committee is the role of the committee secretary and committee staff. But from the council service, we do provide committee secretaries with PDFs of any proposed amendment or substitute that's going to be before a committee. And the only exception is that our duty of confidentiality does flow directly to you as legislators. And so if you were to tell us not to distribute that amendment, we do follow your direction on that. But that is the common practice to deliver the PDFs to the committee secretary.
# Speaker B: And then they get put online while they're being discussed.
# Speaker C: Mr. Chair, in the, in the Senate, that has been the practice last year.
# Speaker A: Okay. And we've done that as soon as they're adopted. But we can't put the amendment on because we don't know if it's going to pass or not. So the amendment in the PDF is not put online. Ling just told me, until the amendment passes, because we don't know what it does. I mean, we have copies of the amendments. The sponsor could give them to whoever they wanted if they want to share the amendment. If you don't want to share the amendment, that's a legislator's prerogative. But they're not put up there for discussion purposes because the bill hasn't been amended. And so until they're amended, the amendment's not on there. And then if you want to amend the bill. If you want us to draft an amendment, amend the bill entirely. We'd have to get the amendment drafted in the bill and then bring the bill back down and then know where the amendments are, which could be a one or two day process, depending on how big the bill is.
# Speaker B: Anyway, Mr. Chair, to the extent possible, I just personally like putting it out there ahead of time, including putting it online, which probably can be done just as well as after the fact. And so just like a bill we vote on that hasn't been adopted. But anyway, I'll just. That's how I feel about it, you know, Mr. Chair, and the same usual deal. So appreciate the discussion. Thank you.
# Speaker A: We all have text messaging, so the lobbyists can text us if they like the amendments or not.
# Speaker B: Sure.
# Speaker A: Probably had some play in the amendment process. Anyway, Senator Gonzalez, thank you.
# Speaker B: And we also have to take the advice from counsel because sometimes he turns into a substitute.
# Speaker A: Any other questions? We're going to be as transparent as we can, but you know, we get moving in certain times and it's just we can't. I can't manage every little detail. So you're here to talk to us about bills and.
# Speaker C: Thank you, Mr. Chair. Yes.
# Speaker A: You're gonna sing the old song.
# Speaker C: So I was requested, Mr. Chair.
# Speaker A: Oh, wait now, Senator Gonzalez, we're gonna need to go into executive. Now you want to make a motion, Mr.
# Speaker C: Chair? Some move that we go into executive session.
# Speaker A: Second Senator Shindo, any objection to going to executive. No, we're not talking about personnel, we're going to talk about bills.
# Speaker C: It.

# %%
print(transcript.export_subtitles_srt())
# Out:
# 1
# 00:00:00,160 --> 00:00:03,624
# We don't have the capability of a scanner, so you can't scan
#
# 2
# 00:00:03,672 --> 00:00:07,128
# and put the amendment up if you send it to us a day before.
#
# 3
# 00:00:07,184 --> 00:00:09,432
# I don't even know if there's a scanner in the building. I think there may
#
# 4
# 00:00:09,456 --> 00:00:11,780
# be one downstairs in the clerk's office.
#
# 5
# 00:00:14,320 --> 00:00:17,720
# And so putting stuff
#
# 6
# 00:00:17,800 --> 00:00:21,608
# electronically up amendments is something
#
# 7
# 00:00:21,664 --> 00:00:25,480
# New Mexico has fallen behind with technology driven access.
#
# 8
# 00:00:25,600 --> 00:00:28,764
# Well, Mr. Chair, I think it's actually a rule now. We've passed
#
# 9
# 00:00:28,872 --> 00:00:32,708
# a law, maybe even said, Representative McQueen, saying that all amendments would actually
#
# 10
# 00:00:32,764 --> 00:00:35,780
# have to be posted online. This may be the only,
#
# 11
# 00:00:35,900 --> 00:00:40,200
# maybe all due respect, that we don't post these amendments, these documents.
#
# 12
# 00:00:40,940 --> 00:00:44,660
# And I just think we should. I think it's public information
#
# 13
# 00:00:44,780 --> 00:00:48,644
# and I just think nothing could be more important than a $10 billion budget
#
# 14
# 00:00:48,772 --> 00:00:51,636
# from a policy standpoint and everything contained in it.
#
# 15
# 00:00:51,788 --> 00:00:55,252
# So I think, Shawn, I mean, with all the other committees and
#
# 16
# 00:00:55,276 --> 00:00:58,908
# legislature amendments because of that rule, what is the common practice of things
#
# 17
# 00:00:58,964 --> 00:01:05,180
# being put online and how
#
# 18
# 00:01:05,220 --> 00:01:06,680
# timely are those really?
#
# 19
# 00:01:08,420 --> 00:01:12,828
# Mr. Chair, Senator, you're correct. The joint rule was passed
#
# 20
# 00:01:13,004 --> 00:01:16,560
# a year or so ago. Last year was the first year of implementation.
#
# 21
# 00:01:17,860 --> 00:01:21,452
# The posting of the amendments received by committees or when they're put
#
# 22
# 00:01:21,476 --> 00:01:24,828
# on in the committee is the role of the committee secretary and committee
#
# 23
# 00:01:24,884 --> 00:01:28,728
# staff. But from the council service, we do provide committee
#
# 24
# 00:01:28,784 --> 00:01:32,856
# secretaries with PDFs of any proposed amendment or substitute
#
# 25
# 00:01:32,968 --> 00:01:36,440
# that's going to be before a committee. And the only exception is
#
# 26
# 00:01:36,480 --> 00:01:40,152
# that our duty of confidentiality does flow
#
# 27
# 00:01:40,216 --> 00:01:44,120
# directly to you as legislators. And so if you were to tell us not
#
# 28
# 00:01:44,160 --> 00:01:47,912
# to distribute that amendment, we do follow your direction on
#
# 29
# 00:01:47,936 --> 00:01:51,576
# that. But that is the common practice to deliver the PDFs
#
# 30
# 00:01:51,608 --> 00:01:55,168
# to the committee secretary. And then they get put online while they're
#
# 31
# 00:01:55,184 --> 00:01:58,320
# being discussed. Mr. Chair, in the,
#
# 32
# 00:01:58,360 --> 00:02:02,208
# in the Senate, that has been the practice last year. Okay. And we've
#
# 33
# 00:02:02,224 --> 00:02:05,584
# done that as soon as they're adopted. But we can't put the amendment
#
# 34
# 00:02:05,632 --> 00:02:09,104
# on because we don't know if it's going to pass or not. So the amendment
#
# 35
# 00:02:09,152 --> 00:02:12,512
# in the PDF is not put online. Ling just told me, until the
#
# 36
# 00:02:12,536 --> 00:02:16,400
# amendment passes, because we don't know what it does. I mean, we have
#
# 37
# 00:02:16,440 --> 00:02:20,202
# copies of the amendments. The sponsor could give them to whoever they wanted if
#
# 38
# 00:02:20,226 --> 00:02:22,794
# they want to share the amendment. If you don't want to share the amendment,
#
# 39
# 00:02:22,842 --> 00:02:24,910
# that's a legislator's prerogative.
#
# 40
# 00:02:25,570 --> 00:02:28,730
# But they're not put up there for discussion purposes because
#
# 41
# 00:02:28,770 --> 00:02:31,630
# the bill hasn't been amended. And so until they're amended,
#
# 42
# 00:02:32,770 --> 00:02:35,866
# the amendment's not on there. And then if you want to amend the bill.
#
# 43
# 00:02:36,018 --> 00:02:38,602
# If you want us to draft an amendment,
#
# 44
# 00:02:38,746 --> 00:02:42,362
# amend the bill entirely. We'd have to get the amendment
#
# 45
# 00:02:42,426 --> 00:02:46,420
# drafted in the bill and then bring the bill back down and
#
# 46
# 00:02:46,460 --> 00:02:49,732
# then know where the amendments are, which could be a one
#
# 47
# 00:02:49,756 --> 00:02:52,640
# or two day process, depending on how big the bill is.
#
# 48
# 00:02:54,620 --> 00:02:58,356
# Anyway, Mr. Chair, to the extent possible, I just personally like
#
# 49
# 00:02:58,428 --> 00:03:02,116
# putting it out there ahead of time, including putting it online,
#
# 50
# 00:03:02,188 --> 00:03:06,100
# which probably can be done just as well as after the fact.
#
# 51
# 00:03:06,220 --> 00:03:09,978
# And so just like a bill we vote on that hasn't
#
# 52
# 00:03:09,994 --> 00:03:13,274
# been adopted. But anyway, I'll just. That's how I feel about it,
#
# 53
# 00:03:13,282 --> 00:03:16,842
# you know, Mr. Chair, and the same usual deal. So appreciate the discussion.
#
# 54
# 00:03:16,906 --> 00:03:20,234
# Thank you. We all have text messaging, so the lobbyists
#
# 55
# 00:03:20,282 --> 00:03:23,530
# can text us if they like the amendments or not. Sure. Probably had some play
#
# 56
# 00:03:23,570 --> 00:03:26,458
# in the amendment process. Anyway, Senator Gonzalez,
#
# 57
# 00:03:26,554 --> 00:03:29,754
# thank you. And we also have to take the
#
# 58
# 00:03:29,842 --> 00:03:33,870
# advice from counsel because sometimes he turns into a substitute.
#
# 59
# 00:03:38,950 --> 00:03:42,542
# Any other questions? We're going to be as transparent as we
#
# 60
# 00:03:42,566 --> 00:03:46,238
# can, but you know, we get moving in
#
# 61
# 00:03:46,294 --> 00:03:50,350
# certain times and it's just we can't.
#
# 62
# 00:03:50,430 --> 00:03:52,490
# I can't manage every little detail.
#
# 63
# 00:03:53,190 --> 00:03:56,414
# So you're here to
#
# 64
# 00:03:56,422 --> 00:03:59,886
# talk to us about bills and. Thank you, Mr.
#
# 65
# 00:03:59,918 --> 00:04:02,530
# Chair. Yes. You're gonna sing the old song.
#
# 66
# 00:04:05,140 --> 00:04:07,628
# So I was requested, Mr. Chair. Oh,
#
# 67
# 00:04:07,644 --> 00:04:12,172
# wait now, Senator Gonzalez, we're gonna need to go into executive. Now you
#
# 68
# 00:04:12,196 --> 00:04:15,772
# want to make a motion, Mr. Chair? Some move that we go into executive
#
# 69
# 00:04:15,876 --> 00:04:19,644
# session. Second Senator Shindo,
#
# 70
# 00:04:19,692 --> 00:04:21,480
# any objection to going to executive.
#
# 71
# 00:04:25,940 --> 00:04:29,116
# No, we're not talking about personnel, we're going to talk about bills.

# %%
transcript.auto_highlights

# %% [markdown]
# ### Summarize transcript

# %%
transcriber = aai.Transcriber()

audio_url = r"N:\Open_LLM\spch_dirz\audio\sanet_finance.wav"

transcript = transcriber.transcribe(audio_url)

# %%
prompt = "Provide a brief summary of the transcript."

result = transcript.lemur.task(
    prompt, final_model=aai.LemurModel.claude3_5_sonnet
)

print(result.response)
# Out:
# ---------------------------------------------------------------------------
# LemurError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 prompt = "Provide a brief summary of the transcript."
# ----> 3 result = transcript.lemur.task(
#       4     prompt, final_model=aai.LemurModel.claude3_5_sonnet
#       5 )
#       7 print(result.response)
#
# File c:\Users\novil\anaconda3\envs\dafl_budget\Lib\site-packages\assemblyai\lemur.py:467, in Lemur.task(self, prompt, context, final_model, max_output_size, timeout, temperature, input_text)
#     440 def task(
#     441     self,
#     442     prompt: str,
#    (...)
#     448     input_text: Optional[str] = None,
#     449 ) -> types.LemurTaskResponse:
#     450     """
#     451     Task feature allows you to submit a custom prompt to the model.
#     452
#    (...)
#     464     Returns: A response to a question or task submitted via custom prompt (with source transcripts or other sources taken into the context)
#     465     """
# --> 467     return self._impl.task(
#     468         prompt=prompt,
#     469         context=context,
#     470         final_model=final_model,
#     471         max_output_size=max_output_size,
#     472         timeout=timeout,
#     473         temperature=temperature,
#     474         input_text=input_text,
#     475     )
#
# File c:\Users\novil\anaconda3\envs\dafl_budget\Lib\site-packages\assemblyai\lemur.py:113, in _LemurImpl.task(self, prompt, context, final_model, max_output_size, timeout, temperature, input_text)
#     103 def task(
#     104     self,
#     105     prompt: str,
#    (...)
#     111     input_text: Optional[str],
#     112 ):
# --> 113     response = api.lemur_task(
#     114         client=self._client.http_client,
#     115         request=types.LemurTaskRequest(
#     116             sources=self._sources,
#     117             prompt=prompt,
#     118             context=context,
#     119             final_model=final_model,
#     120             max_output_size=max_output_size,
#     121             temperature=temperature,
#     122             input_text=input_text,
#     123         ),
#     124         http_timeout=timeout,
#     125     )
#     127     return response
#
# File c:\Users\novil\anaconda3\envs\dafl_budget\Lib\site-packages\assemblyai\api.py:366, in lemur_task(client, request, http_timeout)
#     357 response = client.post(
#     358     f"{ENDPOINT_LEMUR}/task",
#     359     json=request.dict(
#    (...)
#     362     timeout=http_timeout,
#     363 )
#     365 if response.status_code != httpx.codes.OK:
# --> 366     raise types.LemurError(
#     367         f"failed to call Lemur task: {_get_error_message(response)}",
#     368         response.status_code,
#     369     )
#     371 return types.LemurTaskResponse.parse_obj(response.json())
#
# LemurError: failed to call Lemur task: Your account does not have access to LeMUR. Please upgrade or contact us at support@assemblyai.com for more information.
